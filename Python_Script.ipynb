# %%
#STYLE OF USER
#All values are defined as 0 at the beginning of this script

#Norms and Values
Openness = Enhancement = Conservation = Transcendence = 0

#Personality
O = C = E = A = N = 0

#Subculture
Athlete = Biker = Bro = Emo = Footballer = Geek = Goth = Grunge = HipHop = Hipster = Influencer = Minimalist = Punk = Rocker = Skater = Surfer = 0;

#Sustainability
Sustainability = 0

#Clothing Style
Colourful = Luxurious = Outspoken = Fashionable = Informal = 0

#Trends
SuperchargedSimplicity = RerootedNature = Awestruck = 0

#Relation of Frames with Style
StyleRelation = 0

#Concern about Style (of Frames)
StyleConcern = 0

#----------------------------------------------

#QUESTIONS FROM QUESTIONNAIRE

#Music Taste
print("Choices: Classical, Country, EDM, Jazz, Metal, Pop, Punk, Rap, RB, Rock")
musicTaste = []
musicTaste.append(input("Music Taste 1: "))
musicTaste.append(input("Music Taste 2: "))
musicTaste.append(input("Music Taste 3: "))

#(dis)Liked Celebrities
print("Choices: Eminem, Marley, Rotten, Beckham, Jagger, Sioux, Hawk, Rogan, Cobain, Bolt, Tyson, Jenner")
likedCelebs = []
likedCelebs.append(input("Liked Celebrity 1: "))
likedCelebs.append(input("Liked Celebrity 2: "))
likedCelebs.append(input("Liked Celebrity 3: "))

dislikedCelebs = []
dislikedCelebs.append(input("Disliked Celebrity 1: "))
dislikedCelebs.append(input("Disliked Celebrity 2: "))
dislikedCelebs.append(input("Disliked Celebrity 3: "))

#Preferred Environment
print("Choices: Home, Forest, Party")
likedEnvironment = input("Liked Environment: ")
dislikedEnvironment = input("Disliked Environment: ")

#Images of Trends
print("Choices: Simplicity, Nature, Awestruck")
likedTrend = input("Liked Trend: ")
dislikedTrend = input("Disliked Trend: ")

#Choice of Clothing
print("Choices: Comfortable, Casual, Fashionable, Luxurious")
clothingChoice = []
clothingChoice.append(input("Chosen Clothing at Date: "))
clothingChoice.append(input("Chosen Clothing at Home: "))
clothingChoice.append(input("Chosen Clothing at Work: "))
clothingChoice.append(input("Chosen Clothing at Festival: "))
clothingChoice.append(input("Chosen Clothing in Winter: "))

#Brand Preference
print("Choices: HM, Nike, Lauren, Gucci")
likedBrand = input("Liked Brand: ")
dislikedBrand = input("Disliked Brand: ")

#Necessity of Glasses
print("Choices (multiple possible): Reading, Computer, Car, Presentations, All, Aesthetics")
print("If no input left write hyphen (-)")
necessityGlasses = []
necessityGlasses.append(input("Glasses Function 1: "))
necessityGlasses.append(input("Glasses Function 2: "))
necessityGlasses.append(input("Glasses Function 3: "))

#Reason buying Glasses
print("Choices: Eyesight, Style, First")
purchaseReason = input("Purchase Reason: ")

#Relation of Glasses with Style
print("Choices: Functional, Style, Person")
styleConnection = input("Relation with Style: ")

#Purchase Regularity
print("Choices: twoYears, oneYear, halfYear, First")
purchaseRegularity = input("Purchase Regularity: ")

#Amount of Glasses Regulary Worn
print("Choices: One, Two, Three")
glassesAmount = input("Amount of Glasses Regularly Worn: ")

#Preferred Production Processes
print("Choices: Democratic, Local, Natural, Craftsmanship, Innovative, Price, Nothing")
print("If no input write hyphen (-)")
productionProcesses = []
productionProcesses.append(input("Production Process 1: "))
productionProcesses.append(input("Production Process 2: "))
productionProcesses.append(input("Production Process 3: "))
productionProcesses.append(input("Production Process 4: "))
productionProcesses.append(input("Production Process 5: "))
productionProcesses.append(input("Production Process 6: "))
# Out:
# Choices: Classical, Country, EDM, Jazz, Metal, Pop, Punk, Rap, RB, Rock
# Music Taste 1: EDM
# Music Taste 2: Pop
# Music Taste 3: RB
# Choices: Eminem, Marley, Rotten, Beckham, Jagger, Sioux, Hawk, Rogan, Cobain, Bolt, Tyson, Jenner
# Liked Celebrity 1: Beckham
# Liked Celebrity 2: Rogan
# Liked Celebrity 3: Jenner
# Disliked Celebrity 1: Marley
# Disliked Celebrity 2: Sioux
# Disliked Celebrity 3: Bolt
# Choices: Home, Forest, Party
# Liked Environment: Home
# Disliked Environment: Forest
# Choices: Simplicity, Nature, Awestruck
# Liked Trend: Simplicity
# Disliked Trend: Nature
# Choices: Comfortable, Casual, Fashionable, Luxurious
# Chosen Clothing at Date: Fashionable
# Chosen Clothing at Home: Comfortable
# Chosen Clothing at Work: Luxurious
# Chosen Clothing at Festival: Fashionable
# Chosen Clothing in Winter: Comfortable
# Choices: HM, Nike, Lauren, Gucci
# Liked Brand: Lauren
# Disliked Brand: HM
# ...

# %%
#CONNECTIONS TO USER'S STYLE

#Music Taste
for taste in musicTaste:
    if taste == "Classical":
        O += 2
        E -= 1
        Geek += 2
        Emo += 1
        Colourful -= 2
        Luxurious += 1
        Outspoken -= 2
        Fashionable -= 1
        Informal -= 2
    elif taste == "Country":
        O += 2
        A += 2
        Biker += 1
        Colourful += 1
        Luxurious -= 1
        Outspoken -= 1
        Fashionable -= 1
        Informal -= 1
    elif taste == "EDM":
        O += 1
        Colourful += 1
        Luxurious -= 1
        Outspoken += 1
        Fashionable += 1
        Informal += 1
    elif taste == "Jazz":
        O += 2
        N -= 1
        Colourful -= 1
        Luxurious += 1
        Outspoken -= 1
        Fashionable -= 1
        Informal -= 1
    elif taste == "Metal":
        E -= 1
        A -= 1
        Grunge += 3
        Rocker += 2
        Goth += 2
        Punk += 1
        Emo += 1
        Colourful -= 2
        Luxurious -= 2
        Outspoken -= 1
        Fashionable -= 2
        Informal += 1
    elif taste == "Pop":
        E += 1
        A += 1
        Colourful += 2
        Luxurious += 1
        Outspoken += 1
        Fashionable += 2
        Informal -= 1
    elif taste == "Punk":
        C -= 1
        Punk += 3
        Rocker += 1
        Goth += 1
        Colourful -= 1
        Luxurious -= 2
        Outspoken += 2
        Fashionable -= 2
        Informal += 2
    elif taste == "Rap":
        E += 2
        N -= 1
        HipHop += 3
        Skater += 1
        Colourful += 1
        Luxurious -= 1
        Outspoken += 1
        Fashionable += 1
        Informal += 1
    elif taste == "R&B":
        E += 2
        HipHop +=2
        Surfer += 1
        Colourful -= 1
        Luxurious += 1
        Outspoken += 1
        Fashionable += 1
        Informal += 1
    elif taste == "Rock":
        O -= 1
        E -= 1
        N += 1
        Rocker += 3
        Biker += 2
        Emo += 2
        Grunge += 2
        Colourful -= 2
        Luxurious -= 1
        Outspoken -= 1
        Fashionable -= 1
        Informal += 1

#(dis)Liked Celebrities
for celeb in likedCelebs:
    if celeb == "Eminem":
        HipHop += 3
        Openness += 2
    elif celeb == "Marley":
        Hipster += 2
        Minimalist += 2
        Skater += 1
        Surfer += 1
        Transcendence += 2
    elif celeb == "Rotten":
        Punk += 3
        Rocker += 1
        Goth += 1
        Conservation -= 2
        Openness += 1
    elif celeb == "Beckham":
        Footballer += 3
        Athlete += 2
        Influencer += 1
        Enhancement += 2
    elif celeb == "Jagger":
        Rocker += 3
        Biker += 2
        Conservation += 2
    elif celeb == "Sioux":
        Goth += 3
        Emo += 2
        Rocker += 1
        Openness += 2
    elif celeb == "Hawk":
        Skater += 3
        Surfer += 2
        Athlete += 1
        Transcendence += 2
    elif celeb == "Rogan":
        Bro += 3
        Enhancement += 2
    elif celeb == "Cobain":
        Grunge += 3
        Emo += 2
        Rocker += 1
        Punk += 1
        Goth += 1
        Conservation += 2
    elif celeb == "Bolt":
        Athlete += 3
        Footballer += 1
        Openness += 2
    elif celeb == "Tyson":
        Geek += 3
        Transcendence += 2
    elif celeb == "Jenner":
        Influencer += 3
        HipHop += 1
        Enhancement += 2
        
for celeb in dislikedCelebs:
    if celeb == "Eminem":
        HipHop -= 3
        Openness -= 2
    elif celeb == "Marley":
        Hipster -= 2
        Minimalist -= 2
        Skater -= 1
        Surfer -= 1
        Transcendence -= 2
    elif celeb == "Rotten":
        Punk -= 3
        Rocker -= 1
        Goth -= 1
        Conservation += 2
        Openness -= 1
    elif celeb == "Beckham":
        Footballer -= 3
        Athlete -= 2
        Influencer -= 1
        Enhancement -= 2
    elif celeb == "Jagger":
        Rocker -= 3
        Biker -= 2
        Conservation -= 2
    elif celeb == "Sioux":
        Goth -= 3
        Emo -= 2
        Rocker -= 1
        Openness -= 2
    elif celeb == "Hawk":
        Skater -= 3
        Surfer -= 2
        Athlete -= 1
        Transcendence -= 2
    elif celeb == "Rogan":
        Bro -= 3
        Enhancement -= 2
    elif celeb == "Cobain":
        Grunge -= 3
        Emo -= 2
        Rocker -= 1
        Punk -= 1
        Goth -= 1
        Conservation -= 2
    elif celeb == "Bolt":
        Athlete -= 3
        Footballer -= 1
        Openness -= 2
    elif celeb == "Tyson":
        Geek -= 3
        Transcendence -= 2
    elif celeb == "Jenner":
        Influencer -= 3
        HipHop -= 1
        Enhancement -= 2
        
#Preferred Environment
if likedEnvironment == "Home":
    O -= 2
    C += 2
    E -= 2
    A += 1
    N += 1
    SuperchargedSimplicity += 2
elif likedEnvironment == "Forest":
    O += 1
    C += 1
    E -= 1
    A -= 1
    N -= 1
    RerootedNature += 2
elif likedEnvironment == "Party":
    O += 2
    C -= 1
    E += 2
    A += 1
    N -= 1
    Awestruck += 2
    
if dislikedEnvironment == "Home":
    O += 2
    C -= 2
    E += 2
    A -= 1
    N -= 1
    SuperchargedSimplicity -= 2
elif dislikedEnvironment == "Forest":
    O -= 1
    C -= 1
    E += 1
    A += 1
    N += 1
    RerootedNature -= 2
elif dislikedEnvironment == "Party":
    O -= 2
    C += 1
    E -= 2
    A -= 1
    N += 1
    Awestruck -= 2
    
#Images of Trends
if likedTrend == "Simplicity":
    O -= 1
    C += 2
    E -= 1
    A += 1
    N += 1
    SuperchargedSimplicity += 2
elif likedTrend == "Nature":
    O += 1
    C += 1
    E -= 1
    A -= 1
    N -= 1
    RerootedNature += 2
elif likedTrend == "Awestruck":
    O += 2
    C -= 1
    E += 2
    A += 1
    N -= 1
    Awestruck += 2
    
if dislikedTrend == "Simplicity":
    O += 1
    C -= 2
    E += 1
    A -= 1
    N -= 1
    SuperchargedSimplicity -= 2
elif dislikedTrend == "Nature":
    O -= 1
    C -= 1
    E += 1
    A += 1
    N += 1
    RerootedNature -= 2
elif dislikedTrend == "Awestruck":
    O -= 2
    C += 1
    E -= 2
    A -= 1
    N += 1
    Awestruck -= 2
    
#Choice of Clothing
#Choices: Comfortable, Casual, Fashionable, Luxurious
for clothing in clothingChoice:
    if clothing == "Comfortable":
        O -= 2
        C += 2
        E -= 2
        A += 1
        N += 1
        Minimalist += 2
        Geek += 1
        Skater += 1
        Colourful -= 1
        Luxurious -= 2
        Outspoken -= 2
        Fashionable -= 2
        Informal += 2
        StyleConcern -= 2
    elif clothing == "Casual":
        O -= 1
        C += 1
        E -= 1
        A += 1
        N -= 1
        Footballer += 1
        Rocker += 1
        Biker += 1
        Surfer += 1
        Colourful -= 1
        Luxurious -= 1
        Outspoken -= 1
        Fashionable -= 1
        Informal += 1
        StyleConcern -= 1
    elif clothing == "Fashionable":
        O += 1
        C -= 1
        E += 1
        A -= 1
        N -= 1
        Athlete += 1
        Influencer += 1
        HipHop += 1
        Colourful += 1
        Luxurious += 1
        Outspoken += 1
        Fashionable += 1
        Informal -= 1
        StyleConcern += 1
    elif clothing == "Luxurious":
        O += 2
        C -= 2
        E += 2
        A -= 1
        N += 1
        Influencer += 3
        Colourful += 2
        Luxurious += 2
        Outspoken += 2
        Fashionable += 2
        Informal -= 1
        StyleConcern += 2
        
#Brand Preference
#Choices: HM, Nike, Lauren, Gucci
if likedBrand == "HM":
    Conservation += 2
    O -= 1
    C += 2
    E -= 2
    A += 1
    N -= 2
    Biker += 1
    Emo += 1
    Geek += 1
    Goth += 1
    Grunge += 1
    Hipster += 1
    Minimalist += 1
    Punk += 1
    Rocker += 1
    Colourful += 1
    Luxurious -= 1
    Outspoken -= 1
    Fashionable += 1
    Informal -= 1
elif likedBrand == "Nike":
    Conservation += 1
    O -= 1
    C += 1
    E += 1
    A += 1
    N += 1
    HipHop += 2
    Athlete += 2
    Footballer += 2
    Skater += 1
    Surfer += 1
    Colourful -= 1
    Luxurious -= 2
    Outspoken += 1
    Fashionable -= 1
    Informal += 2
elif likedBrand == "Lauren":
    Enhancement += 1
    O += 1
    C -= 1
    E += 1
    A -= 1
    N += 1
    Influencer += 2
    Bro += 2
    Footballer += 1
    Athlete += 1
    Colourful += 2
    Luxurious += 1
    Outspoken += 1
    Fashionable += 2
    Informal -= 2
elif likedBrand == "Gucci":
    Enhancement += 2
    O += 1
    C -= 2
    E += 2
    A -= 1
    N += 2
    Influencer += 3
    Bro += 2
    HipHop += 1
    Colourful += 2
    Luxurious += 2
    Outspoken += 2
    Fashionable += 2
    Informal += 1
    
if dislikedBrand == "HM":
    Conservation -= 2
    O += 1
    C -= 2
    E += 2
    A -= 1
    N += 2
    Biker -= 1
    Emo -= 1
    Geek -= 1
    Goth -= 1
    Grunge -= 1
    Hipster -= 1
    Minimalist -= 1
    Punk -= 1
    Rocker -= 1
    Colourful -= 1
    Luxurious += 1
    Outspoken += 1
    Fashionable -= 1
    Informal += 1
elif dislikedBrand == "Nike":
    Conservation -= 1
    O += 1
    C -= 1
    E -= 1
    A -= 1
    N -= 1
    HipHop -= 2
    Athlete -= 2
    Footballer -= 2
    Skater -= 1
    Surfer -= 1
    Colourful += 1
    Luxurious += 2
    Outspoken -= 1
    Fashionable += 1
    Informal -= 2
elif dislikedBrand == "Lauren":
    Enhancement -= 1
    O -= 1
    C += 1
    E -= 1
    A += 1
    N -= 1
    Influencer -= 2
    Bro -= 2
    Footballer -= 1
    Athlete -= 1
    Colourful -= 2
    Luxurious -= 1
    Outspoken -= 1
    Fashionable -= 2
    Informal += 2
elif dislikedBrand == "Gucci":
    Enhancement -= 2
    O -= 1
    C += 2
    E -= 2
    A += 1
    N -= 2
    Influencer -= 3
    Bro -= 2
    HipHop -= 1
    Colourful -= 2
    Luxurious -= 2
    Outspoken -= 2
    Fashionable -= 2
    Informal -= 1
    
#Necessity of Glasses
#Choices (multiple possible): Reading, Computer, Car, Presentations, All, Aesthetics
#If no input write hyphen (-)
for function in necessityGlasses:
    if function == "Reading":
        StyleRelation -= 1
    elif function == "Computer":
        StyleRelation -= 1
    elif function == "Car":
        StyleRelation += 1
    elif function == "Presentations":
        StyleRelation += 1
    elif function == "All":
        StyleRelation += 2
    elif function == "Aesthetics":
        StyleRelation += 2

#Reason buying Glasses
#Choices: Eyesight, Style, First
if purchaseReason == "Eyesight":
    StyleRelation -= 2
    StyleConcern -= 2
elif purchaseReason == "Style":
    StyleRelation += 2
    StyleConcern += 2

#Connection of Glasses with Style
#Choices: Functional, Style, Person
if styleConnection == "Functional":
    StyleRelation -= 4
    StyleConcern -= 2
elif styleConnection == "Style":
    StyleRelation += 2
    StyleConcern += 1
elif styleConnection == "Person":
    StyleRelation += 4
    StyleConcern += 2

#Purchase Regularity
#Choices: twoYears, oneYear, halfYear, First
if purchaseRegularity == "twoYears":
    Sustainability += 1
    SuperchargedSimplicity += 2
    RerootedNature += 1
    Awestruck -= 1
elif purchaseRegularity == "oneYear":
    SuperchargedSimplicity += 1
    RerootedNature += 1
    Awestruck -= 1
    StyleRelation += 1
    StyleConcern += 1
elif purchaseRegularity == "halfYear":
    Sustainability -= 1
    SuperchargedSimplicity -= 2
    RerootedNature -= 1
    Awestruck += 1
    StyleRelation += 2
    StyleConcern += 2

#Amount of Glasses Regulary Worn
#Choices: One, Two, Three
if glassesAmount == "One":
    Sustainability += 1
    SuperchargedSimplicity += 2
    RerootedNature += 1
    Awestruck -= 1
elif glassesAmount == "Two":
    Sustainability -= 1
    SuperchargedSimplicity -= 1
    RerootedNature -= 1
    Awestruck += 1
elif glassesAmount == "Three":
    Sustainability -= 2
    SuperchargedSimplicity -= 2
    RerootedNature -= 2
    Awestruck += 1

#Preferred Production Processes
#Choices: Democratic, Local, Natural, Crafstmanship, Innovative, Price, Nothing
#If no input write hyphen (-)
for process in productionProcesses:
    if process == "Democratic":
        Transcendence += 2
        Sustainability += 1
        SuperchargedSimplicity += 2
        RerootedNature += 1
    elif process == "Local":
        Transcendence += 2
        Sustainability += 2
        SuperchargedSimplicity += 1
        RerootedNature += 2
    elif process == "Natural":
        Transcendence += 1
        Sustainability += 2
        RerootedNature += 2
    elif process == "Craftsmanship":
        Openness += 2
        Awestruck += 1
    elif process == "Innovative":
        Openness += 2
        Awestruck += 2
    elif process == "Price":
        Conservation += 2
        SuperchargedSimplicity -= 1
        Awestruck -= 1
    elif process == "Nothing":
        Conservation += 1
        Transcendence -= 1
        Openness -= 1
        RerootedNature -= 2

# %%
print("STYLE OF USER RESULTS")
#All values are defined as 0 at the beginning of this script

print("")

print("Norms and Values")
print("Openness to change [-1|4]: " + str(Openness))
print("Self-enhancement [0|3]: "+ str(Enhancement))
print("Conservation [0|6]: " + str(Conservation))
print("Self-transcendence [-1|5]: " + str(Transcendence))

print("")

print("Personality")
print("Openness to experience [-16|22]: " + str(O))
print("Conscientiousness [-17|18]: " + str(C))
print("Extraversion [-20|23]: " + str(E))
print("Agreeableness [-10|12]: " + str(A))
print("Neuroticism [-13|13]: " + str(N))

print("")

print("Subculture")
print("Athlete: " + str(Athlete))
print("Biker: " + str(Biker))
print("Bro: " + str(Bro))
print("Emo: " + str(Emo))
print("Footballer: " + str(Footballer))
print("Geek: " + str(Geek))
print("Goth: " + str(Goth))
print("Grunge: " + str(Grunge))
print("Hip-Hop: " + str(HipHop))
print("Hipster: " + str(Hipster))
print("Influencer: " + str(Influencer))
print("Minimalist: " + str(Minimalist))
print("Punk: " + str(Punk))
print("Rocker: " + str(Rocker))
print("Skater: " + str(Skater))
print("Surfer: " + str(Surfer))

print("")

print("Sustainability")
print("Sustainability [-4|6]: " + str(Sustainability))

print("")

print("Clothing Style")
print("Colourful [-14|17]: " + str(Colourful))
print("Luxurious [-19|17]: " + str(Luxurious))
print("Outspoken [-17|17]: " + str(Outspoken))
print("Fashionable [-18|17]: " + str(Fashionable))
print("Informal [-13|18]: " + str(Informal))

print("")

print("Trends")
print("Supercharged Simplicity [-8|15]: " + str(SuperchargedSimplicity))
print("Rerooted Nature [-5|11]: " + str(RerootedNature))
print("Awestruck [-6|11]: " + str(Awestruck))

print("")

print("Relation of Frames with Style")
print("Relation of Frames With Style [-8|8]: " + str(StyleRelation))

print("")

print("Concern about Style (of Frames)")
print("Concern about Style (of Frames) [-14|16]: " + str(StyleConcern))
# Out:
# STYLE OF USER RESULTS
#
# Norms and Values
# Openness to change [-1|4]: 0
# Self-enhancement [0|3]: 7
# Conservation [0|6]: -2
# Self-transcendence [-1|5]: 0
#
# Personality
# Openness to experience [-16|22]: -2
# Conscientiousness [-17|18]: -1
# Extraversion [-20|23]: 3
# Agreeableness [-10|12]: 2
# Neuroticism [-13|13]: 8
#
# Subculture
# Athlete: 2
# Biker: -1
# Bro: 5
# Emo: -3
# Footballer: 3
# Geek: 1
# Goth: -4
# Grunge: -1
# Hip-Hop: 3
# Hipster: -3
# Influencer: 11
# Minimalist: 1
# Punk: -1
# Rocker: -2
# Skater: 1
# Surfer: -1
#
# Sustainability
# Sustainability [-4|6]: 1
#
# Clothing Style
# Colourful [-14|17]: 6
# Luxurious [-19|17]: 2
# Outspoken [-17|17]: 4
# Fashionable [-18|17]: 4
# Informal [-13|18]: 0
#
# Trends
# Supercharged Simplicity [-8|15]: 5
# Rerooted Nature [-5|11]: -3
# Awestruck [-6|11]: 3
#
# Relation of Frames with Style
# Relation of Frames With Style [-8|8]: -1
#
# Concern about Style (of Frames)
# Concern about Style (of Frames) [-14|16]: -1

# %%
#STYLE OF FRAME
#All values are defined as 0 at the beginning of this script

#Material
Acetate = Metal = Printed = Wood = 0

#Luxury & Details
Luxury = 0

#Background
Quality = Price = Sustainable = Innovation = Nearby = Crafted = 0

#Shape
Eye = Oval = Rectangle = Round = Square = Wayfarer = Aviator = Clubmaster = 0

#Colour
White = Black = Grey = Orange = Yellow = Red = Brown = Green = Pink = Purple = Blue = 0

#Outspokenness
Outspokenness = 0

#Strongness
Strongness = 0
#------------------------------------------

#Norms & Values
if Openness <= 0:
    Printed -= 2
    Luxury += 1
    Innovation -= 2
    Crafted -= 1
elif Openness == 1:
    Metal += 1
    Acetate += 1
elif Openness >= 2:
    Printed += 2
    Luxury -= 1
    Innovation += 2
    Crafted += 1

if Enhancement <= 0:
    Metal -= 2
    Luxury -= 2
    Price -= 2
elif Enhancement == 1:
    Metal += 1
    Acetate += 1
elif Enhancement >= 2:
    Metal += 2
    Luxury += 2
    Price += 2
    
if Conservation <= 0:
    Acetate -= 2
    Luxury += 2
    Quality -= 2
elif Conservation == 1:
    Metal += 1
    Acetate += 1
elif Conservation >= 2:
    Acetate += 2
    Luxury -= 2
    Quality += 2

if Transcendence <= 0:
    Wood -= 2
    Metal -= 1
    Luxury += 1
    Sustainable -= 2
    Nearby -= 2
elif Transcendence == 1:
    Metal += 1
elif Transcendence >= 2:
    Metal += 1
    Wood += 2
    Luxury -= 1
    Sustainable += 2
    Nearby += 2
    
#Personality
if O < -5:
    Luxury -= 2
    Square += 2
    Rectangle += 2
    White += 1
    Black += 1
    Blue += 2
    Grey += 2
    Outspokenness -= 2
    Strongness -= 1
elif -6 < O < 6:
    Round += 2
    Wayfarer += 2
    Clubmaster += 2
    Oval += 2
    Brown += 1
    Green += 1
    Pink += 1
elif O > 5:
    Luxury += 2
    Eye += 2
    Aviator += 2
    Orange += 2
    Red += 2
    Purple += 2
    Yellow += 2
    Outspokenness += 2
    Strongness += 1

if C < -5:
    Luxury += 2
    Eye += 2
    Aviator += 2
    Orange += 1
    Purple += 1
    Outspokenness += 2
    Strongness += 1
elif -6 < C < 6:
    Round += 2
    Wayfarer += 2
    Clubmaster += 2
    Oval += 2
    Black += 1
    Red += 1
    Pink += 1
    Grey += 2
    Yellow += 2
elif C > 5:
    Luxury -= 2
    Square += 2
    Rectangle += 2
    White += 2
    Brown += 2
    Green += 1
    Blue += 2
    Outspokenness -= 2
    Strongness -= 1

if E < -5:
    Luxury -= 2
    Square += 2
    Rectangle += 2
    White += 1
    Green += 1
    Grey += 2
    Yellow += 1
    Outspokenness -= 2
    Strongness -= 1
elif -6 < E < 6:
    Round += 2
    Wayfarer += 2
    Clubmaster += 2
    Oval += 2
    Black += 1
    Brown += 1
    Purple += 1
    Blue += 1
elif E > 5:
    Luxury += 2
    Eye += 2
    Aviator += 2
    Orange += 2
    Red += 2
    Pink += 1
    Outspokenness += 2
    Strongness += 1

if A < -5:
    Luxury += 1
    Eye += 2
    Aviator += 2
    White += 2
    Black += 2
    Grey += 2
    Outspokenness -= 1
    Strongness += 2
elif -6 < A < 6:
    Round += 2
    Wayfarer += 2
    Clubmaster += 2
    Oval += 2
    Red += 1
    Brown += 1
    Purple += 1
elif A > 5:
    Luxury -= 1
    Square += 2
    Rectangle += 2
    Orange += 2
    Green += 2
    Pink += 2
    Blue += 2
    Yellow += 2
    Outspokenness += 1
    Strongness -= 2
    
if N < -5:
    Luxury -= 1
    Square += 2
    Rectangle += 2
    Orange += 2
    Red += 2
    Yellow += 1
    Outspokenness += 1
    Strongness -= 1
elif -6 < N < 6:
    Round += 2
    Wayfarer += 2
    Clubmaster += 2
    Oval += 2
    White += 1
    Pink += 1
    Purple += 1
    Blue += 1
elif N > 5:
    Luxury += 1
    Eye += 2
    Aviator += 2
    Black += 1
    Brown += 1
    Green += 1
    Grey += 2
    Outspokenness -= 1
    Strongness += 1
    
#Subculture
if Athlete > 4:
    Luxury -= 1
    Quality += 2
    Aviator += 2
    Wayfarer += 2
    Clubmaster +=2
    Blue += 2
    Black += 2
    Yellow += 1
if Biker > 4:
    Luxury -= 2
    Price -= 1
    Square += 2
    Black += 1
    Green += 1
if Bro > 4:
    Luxury += 2
    Price += 2
    Aviator +=2
    Black += 2
    White += 1
if Emo > 4:
    Luxury-= 1
    Price -= 1
    Rectangle += 2
    Square += 1
    Black += 2
    White += 2
    Pink += 1
    Green += 1
    Red += 1
if Footballer > 4:
    Luxury += 1
    Price += 1
    Aviator += 2
    Blue += 1
    White += 1
    Black += 2
if Geek > 4:
    Luxury -= 2
    Innovation += 2
    Crafted += 1
    Rectangle += 2
    Grey += 1
    Black += 2
if Goth > 4:
    Luxury -= 2
    Price -= 1
    Eye += 2
    Square += 1
    Black += 2
if Grunge > 4:
    Luxury -= 1
    Price -= 1
    Clubmaster += 2
    Wayfarer += 2
    Round += 1
    Black += 2
    Red += 1
    Grey += 1
    White += 1
    Brown += 1
if HipHop > 4:
    Luxury += 1
    Price += 1
    Round += 2
    Square += 1
    Orange += 2
    Red += 2
    Purple += 2
    Pink += 2
    White += 1
    Black += 1
if Hipster > 4:
    Luxury -= 1
    Sustainable += 2
    Crafted += 2
    Nearby += 1
    Square += 1
    Wayfarer += 1
    Clubmaster += 1
    Black += 2
    White += 2
    Grey += 2
if Influencer > 4:
    Luxury += 2
    Price += 2
    Eye += 2
    Wayfarer += 1
    Clubmaster += 1
    Red += 2
    Black += 1
    Green += 1
    Orange += 2
    Yellow += 2
if Minimalist > 4:
    Luxury -= 2
    Sustainable += 2
    Nearby += 1
    Round += 2
    Square += 2
    White += 2
    Grey += 1
    Black += 1
if Punk > 4:
    Luxury -= 2
    Price -= 1
    Round += 2
    Black += 2
    Red += 1
    Yellow += 1
if Rocker > 4:
    Luxury -= 2
    Price -= 1
    Aviator += 2
    Oval += 1
    Black += 2
    Grey += 1
    Blue += 1
    Green += 1
if Skater > 4:
    Luxury -= 2
    Quality += 2
    Crafted += 1
    Square += 2
    White += 2
    Grey += 1
    Black += 1
    Brown += 1
if Surfer > 4:
    Luxury -= 2
    Quality += 1
    Crafted += 1
    Square += 2
    Pink += 2
    Purple += 2
    Green += 2
    Blue += 2
    Grey += 2
    
#Sustainability
if Sustainability < 0:
    Wood -= 2
    Printed -= 2
    Metal += 1
    Acetate += 1
    Quality -= 1
    Sustainable -= 2
    Nearby -= 2
elif -1 < Sustainability < 4:
    Metal += 1
    Acetate += 1
    Printed += 1
elif Sustainability > 3:
    Wood += 2
    Printed += 2
    Acetate -= 1
    Quality += 1
    Sustainable += 2
    Nearby += 2
    
#Clothing Style
if Colourful < -5:
    Wood += 1
    Metal += 1
    Luxury -= 2
    Square += 2
    Rectangle += 2
    Black += 2
    Grey += 2
    Brown += 2
    White += 1
    Outspokenness -= 2
    Strongness -= 1
elif -6 < Colourful < 6:
    Metal += 1
    Acetate += 1
    Round += 2
    Wayfarer += 2
    Clubmaster += 2
    Oval += 2
    Blue += 2
    Purple += 2
    Green += 2
    White += 1
elif Colourful > 5:
    Printed += 2
    Acetate += 2
    Wood -= 1
    Metal -= 1
    Luxury += 2
    Eye += 2
    Aviator += 2
    Orange += 2
    Red += 2
    Pink += 2
    Yellow += 2
    Outspokenness += 2
    Strongness += 1
    
if Luxurious < -5:
    Wood += 1
    Printed += 1
    Acetate += 2
    Luxury -= 2
    Rectangle += 2
    Square += 1
    Pink += 2
    Orange += 2
    Yellow += 2
    Outspokenness -= 1
    Strongness -= 1
elif -6 < Luxurious < 6:
    Metal += 1
    Acetate += 1
    Oval += 1
    Square += 1
    Eye += 1
    Grey += 2
    Red += 2
    Green += 2
    Brown += 1
elif Luxurious > 5:
    Metal += 2
    Wood -= 2
    Acetate -= 1
    Printed -= 1
    Luxury += 2
    Aviator += 2
    Round += 2
    Wayfarer += 2
    Clubmaster += 2
    White += 2
    Purple += 1
    Blue += 2
    Black += 2
    Outspokenness += 1
    Strongness += 1
    
if Outspoken < -5:
    Metal += 2
    Luxury -= 2
    Square += 2
    Rectangle += 2
    Black += 2
    Grey += 2
    Brown += 2
    White += 1
    Outspokenness -= 2
    Strongness -= 2
elif -6 < Outspoken < 6:
    Round += 2
    Wayfarer += 2
    Clubmaster += 2
    Oval += 2
    Blue += 2
    Purple += 2
    Green += 2
    White += 1
elif Outspoken > 5:
    Metal -= 2
    Luxury += 2
    Eye += 2
    Aviator += 2
    Orange += 2
    Red += 2
    Pink += 2
    Yellow += 2
    Outspokenness += 2
    Strongness += 2
    
if Fashionable < -5:
    Metal += 1
    Acetate -= 1
    Luxury -= 1
    Square += 2
    Rectangle += 2
    Black += 2
    Grey += 2
    Brown += 2
    White += 1
    Outspokenness -= 2
    Strongness -= 1
elif -6 < Fashionable < 6:
    Round += 2
    Wayfarer += 2
    Clubmaster += 2
    Oval += 2
    Blue += 2
    Purple += 2
    Green += 2
    White += 1
elif Fashionable > 5:
    Acetate += 1
    Metal -= 1
    Luxury += 1
    Eye += 2
    Aviator += 2
    Orange += 2
    Red += 2
    Pink += 2
    Yellow += 2
    Outspokenness += 2
    Strongness -= 1
    
if Informal < -5:
    Wood -= 1
    Metal -= 1
    Luxury += 1
    Square += 2
    Rectangle += 2
    Black += 2
    Grey += 2
    Brown += 2
    White += 1
    Outspokenness -= 2
    Strongness += 1
elif -6 < Informal < 6:
    Round += 2
    Wayfarer += 2
    Clubmaster += 2
    Oval += 2
    Blue += 2
    Purple += 2
    Green += 2
    White += 1
elif Informal > 5:
    Wood += 1
    Metal += 1
    Luxury -= 1
    Eye += 2
    Aviator += 2
    Orange += 2
    Red += 2
    Pink += 2
    Yellow += 2
    Outspokenness += 2
    Strongness += 1
    
#Trends
if SuperchargedSimplicity < 0:
    Acetate -= 2
    Quality -= 2
    Sustainable -= 1
    Crafted -= 2
    Eye += 1
    Aviator += 1
    Blue += 1
    Orange += 2
    Red += 2
    Outspokenness += 2
elif -1 < SuperchargedSimplicity < 6:
    Metal += 1
elif SuperchargedSimplicity > 5:
    Acetate += 2
    Quality += 2
    Sustainable += 1
    Crafted += 2
    Round += 2
    Square += 2
    Eye -= 2
    Aviator -= 2
    Black += 2
    Yellow += 1
    Brown += 2
    White += 2
    Blue -= 1
    Orange -= 2
    Red -= 2
    Outspokenness -= 2
    
if RerootedNature < 0:
    Wood -= 2
    Sustainable -= 2
    Nearby -= 2
    Eye += 1
    Aviator += 1
    Square += 1
    Brown -= 2
    Green -= 2
    Outspokenness += 1
elif -1 < RerootedNature < 6:
    Metal += 1
elif RerootedNature > 5:
    Wood += 2
    Sustainable += 2
    Nearby += 2
    Oval += 2
    Round += 2
    Rectangle -= 1
    Brown += 2
    Green += 2
    Yellow += 1
    Blue -= 2
    Orange -= 2
    Red -= 2
    Outspokenness -= 1
    
if Awestruck < 0:
    Printed -= 2
    Innovation -= 2
    Rectangle += 2
    Square += 2
    Outspokenness -= 2
elif -1 < Awestruck < 6:
    Metal += 1
elif Awestruck > 5:
    Printed += 2
    Innovation += 2
    Eye += 1
    Aviator += 1
    Rectangle -= 2
    Blue += 2
    Pink += 2
    Grey += 2
    White += 2
    Red += 1
    Outspokenness += 2
    
#Relation of Frames with Style
if StyleRelation < 0:
    Black += 3
    White += 3
    Grey += 3
    Blue += 3
    Orange -= 4
    Yellow -= 4
    Red -= 4
    Brown -= 4
    Green -= 4
    Pink -= 4
    Purple -= 4
    Outspokenness -= 3
    Strongness -= 4
elif -1 < StyleRelation < 3:
    Blue += 2
    White += 2
    Strongness += 1
elif StyleRelation > 3:
    Outspokenness += 3
    Strongness += 4
    
#Concern about Style (of Frames)
if StyleConcern < -4:
    Luxury -= 2
    Outspokenness -= 3
    Strongness -= 3
elif -5 < StyleConcern < 5:
    Outspokenness += 1
    Strongness += 1
elif StyleConcern > 4:
    Luxury += 2
    Outspokenness += 3
    Strongness += 3

# %%
print("STYLE OF FRAME RESULTS")
#All values are defined as 0 at the beginning of this script

print("Material")
print("Acetate [-7|12]: " + str(Acetate))
print("Metal [-8|14]: " + str(Metal))
print("Printed [-7|9]: " + str(Printed))
print("Wood [-9|9]: " + str(Wood))
      
print("")

print("Luxury & Details")
print("The scores in brackets visualise the possible range where all subcultures are also taken into consideration")
print("Luxury [-24(-44)|24(30)]: " + str(Luxury))

print("")
      
print("Background")
print("Ranges with brackets in them visualise the possible ranges where all subcultures are also taken into consideration")
print("Quality [-6|6(11)]: " + str(Quality))
print("Price [-2(-8)|2(8)]: " + str(Price))
print("Sustainable [-7|7(11)]: " + str(Sustainable))
print("Innovation [-4|4(6)]: " + str(Innovation))
print("Nearby [-6|6(8)]: " + str(Nearby))
print("Crafted [-3|3(8)] " + str(Crafted))

print("")
      
print("Shape")
print("Cat Eye [-2|22(26)]: " + str(Eye))
print("Oval [0|21(22)]: " + str(Oval))
print("Rectangle [-3|22(31)]: " + str(Rectangle))
print("Round [0|23(30)]: " + str(Round))
print("Square [0|23(33)]: " + str(Square))
print("Wayfarer [0|19(24)]: " + str(Wayfarer))
print("Aviator [-2|22(30)]: " + str(Aviator))
print("Clubmaster [0|19(24)]: " + str(Clubmaster))

print("")
      
print("Colour")
print("White [0|19(27)]: " + str(White))
print("Black [0|20(33)]: " + str(Black))
print("Grey [0|22(27)]: " + str(Grey))
print("Orange [-8|21(23)]: " + str(Orange))
print("Yellow [-4|18(22)]: " + str(Yellow))
print("Red [-4|21(28)]: " + str(Red))
print("Brown [-6|19(21)]: " + str(Brown))
print("Green [-6|18(24)]: " + str(Green))
print("Pink [-4|18(23)]: " + str(Pink))
print("Purple [-4|15(19)]: " + str(Purple))
print("Blue [-3|24(30)]: " + str(Blue))

print("")
      
print("Outspokenness")
print("Outspokenness [-26|26]: "+ str(Outspokenness))

print("")
      
print("Strongness")
print("Strongness [-19|19]: " + str(Strongness))
# Out:
# STYLE OF FRAME RESULTS
# Material
# Acetate [-7|12]: 2
# Metal [-8|14]: 4
# Printed [-7|9]: 1
# Wood [-9|9]: -5
#
# Luxury & Details
# The scores in brackets visualise the possible range where all subcultures are also taken into consideration
# Luxury [-24(-44)|24(30)]: 13
#
# Background
# Ranges with brackets in them visualise the possible ranges where all subcultures are also taken into consideration
# Quality [-6|6(11)]: -2
# Price [-2(-8)|2(8)]: 6
# Sustainable [-7|7(11)]: -4
# Innovation [-4|4(6)]: -2
# Nearby [-6|6(8)]: -4
# Crafted [-3|3(8)] -1
#
# Shape
# Cat Eye [-2|22(26)]: 8
# Oval [0|21(22)]: 15
# Rectangle [-3|22(31)]: 0
# Round [0|23(30)]: 14
# Square [0|23(33)]: 2
# Wayfarer [0|19(24)]: 15
# Aviator [-2|22(30)]: 7
# Clubmaster [0|19(24)]: 15
#
# Colour
# White [0|19(27)]: 7
# Black [0|20(33)]: 9
# Grey [0|22(27)]: 9
# Orange [-8|21(23)]: 0
# Yellow [-4|18(22)]: 2
# Red [-4|21(28)]: 4
# Brown [-6|19(21)]: -1
# Green [-6|18(24)]: 5
# Pink [-4|18(23)]: 0
# ...

# %%
#STYLE OF FRAME RESULTS TO FRAME GENERATION
print("Material")
if Acetate < 1:
    print("Don't use Acetate")
elif 0 < Acetate < 6:
    print("Possible to use Acetate")
elif Acetate > 5:
    print("Use Acetate")
    
if Metal < 1:
    print("Don't use Metal")
elif 0 < Metal < 6:
    print("Possible to use Metal")
elif Metal > 5:
    print("Use Metal")
    
if Printed < 1:
    print("Don't use 3D-Printed")
elif 0 < Printed < 6:
    print("Possible to use 3D-Printed")
elif Printed > 5:
    print("Use 3D-Printed")
    
if Wood < 1:
    print("Don't use Wood")
elif 0 < Wood < 6:
    print("Possible to use Wood")
elif Acetate > 5:
    print("Use Wood")

print("")
    
print("Luxury & Details")
print("Luxury Range: Very low, low, Average, High and Very High")
if Luxury < -14:
    print("Luxury level: Very Low")
    print("Very few different details")
    print("Very low outspokenness")
    print("Very little metal or metal details")
    print("Very few different colours")
elif -15 < Luxury < -5:
    print("Luxury level: Low")
    print("Few different details")
    print("Low outspokenness")
    print("Little metal or metal details")
    print("Few different colours")
elif -6 < Luxury < 6:
    print("Luxury level: Average")
    print("Some different details")
    print("Some outspokenness")
    print("Some metal or metal details")
    print("Some different colours")
elif 5 < Luxury < 15:
    print("Luxury level: High")
    print("Many different details")
    print("Much outspokenness")
    print("Much metal or metal details")
    print("Many different colours")
elif Luxury > 14:
    print("Luxury level: Very High")
    print("Very many different details")
    print("A ton of outspokenness")
    print("A ton of metal or metal details")
    print("Very many different colours")

print("")    

print("Background")
print("Range: Low, Average, High")
if Quality < 0:
    print("Quality of Low importance")
elif -1 < Quality < 5:
    print ("Quality of Average importance")
elif Quality > 4:
    print ("Quality of High importance")
    
if Price < 0:
    print("Price can/should be Low")
elif -1 < Price < 3:
    print ("Price can/should be Average")
elif Price > 2:
    print ("Price can/should be High")
    
if Sustainable < 0:
    print("Sustainability of Low importance")
elif -1 < Sustainable < 4:
    print ("Sustainability of Average importance")
elif Sustainable > 3:
    print ("Sustainability of High importance")
    
if Innovation < 0:
    print("Innovation of Low importance")
elif -1 < Innovation < 3:
    print ("Innovation of Average importance")
elif Innovation > 2:
    print ("Innovation of High importance")

if Nearby < 0:
    print("Local Production of Low importance")
elif -1 < Nearby < 4:
    print ("Local Production of Average importance")
elif Nearby > 3:
    print ("Local Production of High importance")

if Crafted < 0:
    print("Craftsmanship of Low importance")
elif -1 < Crafted < 3:
    print ("Craftsmanship of Average importance")
elif Crafted > 2:
    print ("Craftsmanship of High importance")

print("")
    
print("Shape")
print("Range: Do not use, Possible to use, Use and Definitely use")
if Aviator < 7:
    print("Do not use Aviator")
elif 6 < Aviator < 13:
    print("Possible to use Aviator")
elif 12 < Aviator < 19:
    print("Use Aviator")
elif Aviator > 18:
    print("Definitely use Aviator")
    
if Eye < 7:
    print("Do not use Cat Eye")
elif 6 < Eye < 13:
    print("Possible to use Cat Eye")
elif 12 < Eye < 19:
    print("Use Cat Eye")
elif Eye > 18:
    print("Definitely use Cat Eye")

if Oval < 7:
    print("Do not use Oval")
elif 6 < Oval < 13:
    print("Possible to use Oval")
elif 12 < Oval < 19:
    print("Use Oval")
elif Oval > 18:
    print("Definitely use Oval")

if Rectangle < 7:
    print("Do not use Rectangle")
elif 6 < Rectangle < 13:
    print("Possible to use Rectangle")
elif 12 < Rectangle < 19:
    print("Use Rectangle")
elif Rectangle > 18:
    print("Definitely use Rectangle")    
    
if Round < 7:
    print("Do not use Round")
elif 6 < Round < 13:
    print("Possible to use Round")
elif 12 < Round < 19:
    print("Use Round")
elif Round > 18:
    print("Definitely use Round")

if Square < 7:
    print("Do not use Square")
elif 6 < Square < 13:
    print("Possible to use Square")
elif 12 < Square < 19:
    print("Use Square")
elif Square > 18:
    print("Definitely use Square")

if Wayfarer < 7:
    print("Do not use Wayfarer")
elif 6 < Wayfarer < 13:
    print("Possible to use Wayfarer")
elif 12 < Wayfarer < 19:
    print("Use Wayfarer")
elif Wayfarer > 18:
    print("Definitely use Wayfarer")    

if Clubmaster < 7:
    print("Do not use Clubmaster")
elif 6 < Clubmaster < 13:
    print("Possible to use Clubmaster")
elif 12 < Clubmaster < 19:
    print("Use Clubmaster")
elif Clubmaster > 18:
    print("Definitely use Clubmaster")  

print("")
    
print("Colour")
print("Range: Do not use, Possible to use, Use and Definitely use")
if White < 7:
    print("Do not use White")
elif 6 < White < 13:
    print("Possible to use White")
elif 12 < White < 19:
    print("Use White")
elif White > 18:
    print("Definitely use White")  
    
if Black < 7:
    print("Do not use Black")
elif 6 < Black < 13:
    print("Possible to use Black")
elif 12 < Black < 19:
    print("Use Black")
elif Black > 18:
    print("Definitely use Black")

if Grey < 7:
    print("Do not use Grey")
elif 6 < Grey < 13:
    print("Possible to use Grey")
elif 12 < Grey < 19:
    print("Use Grey")
elif Grey > 18:
    print("Definitely use Grey")    

if Orange < 7:
    print("Do not use Orange")
elif 6 < Orange < 13:
    print("Possible to use Orange")
elif 12 < Orange < 19:
    print("Use Orange")
elif Orange > 18:
    print("Definitely use Orange")        

if Yellow < 7:
    print("Do not use Yellow")
elif 6 < Yellow < 13:
    print("Possible to use Yellow")
elif 12 < Yellow < 19:
    print("Use Yellow")
elif Yellow > 18:
    print("Definitely use Yellow")  

if Red < 7:
    print("Do not use Red")
elif 6 < Red < 13:
    print("Possible to use Red")
elif 12 < Red < 19:
    print("Use Red")
elif Red > 18:
    print("Definitely use Red")  
    
if Brown < 7:
    print("Do not use Brown")
elif 6 < Brown < 13:
    print("Possible to use Brown")
elif 12 < Brown < 19:
    print("Use Brown")
elif Brown > 18:
    print("Definitely use Brown")

if Green < 7:
    print("Do not use Green")
elif 6 < Green < 13:
    print("Possible to use Green")
elif 12 < Green < 19:
    print("Use Green")
elif Green > 18:
    print("Definitely use Green")
    
if Pink < 7:
    print("Do not use Pink")
elif 6 < Pink < 13:
    print("Possible to use Pink")
elif 12 < Pink < 19:
    print("Use Pink")
elif Pink > 18:
    print("Definitely use Pink")

if Purple < 7:
    print("Do not use Purple")
elif 6 < Purple < 13:
    print("Possible to use Purple")
elif 12 < Purple < 19:
    print("Use Purple")
elif Purple > 18:
    print("Definitely use Purple")    

if Blue < 7:
    print("Do not use Blue")
elif 6 < Blue < 13:
    print("Possible to use Blue")
elif 12 < Blue < 19:
    print("Use Blue")
elif Blue > 18:
    print("Definitely use Blue") 

print("")

print("Outspokenness")
print("Outspokenness Range: Very low, low, Average, High and Very High")
if Outspokenness < -14:
    print("Outspokenness level: Very How")
    print("Very High Transparency")
    print("Only Desaturated Colours")
    print("Very Few Details")
elif -15 < Outspokenness < -5:
    print("Outspokenness level: Low")
    print("High Transparency")
    print("Mostly Desaturated Colours")
    print("Few Details")
elif -6 < Outspokenness < 6:
    print("Outspokenness level: Average")
    print("Both Transparency and non-transparency possible")
    print("Both Saturated and desaturated colours possible")
    print("Some Details")
elif 5 < Outspokenness < 15:
    print("Outspokenness level: High")
    print("Low to No Transparency")
    print("Mostly Saturated Colours")
    print("Many Details")
elif Outspokenness > 14:
    print("Outspokenness level: Very High")
    print("No Transparency")
    print("Only Saturated Colours")
    print("Very Many Details")

print("")

print("Strongness")
print("Strongness Range: Very low, low, Average, High and Very High")
if Strongness < -10:
    print("Strongness level: Very How")
    print("Very Thin Frames")
    print("Only Desaturated Colours")
elif -11 < Strongness < -4:
    print("Strongness level: Low")
    print("Thin Frames")
    print("Mostly Desaturated Colours")
elif -5 < Strongness < 5:
    print("Strongness level: Average")
    print("Frames of Average Thickness")
    print("Both Saturated and desaturated colours possible")
elif 4 < Strongness < 11:
    print("Strongness level: High")
    print("Thick Frames")
    print("Mostly Saturated Colours")
elif Strongness > 10:
    print("Strongness level: Very High")
    print("Very Thick Frames")
    print("Only Saturated Colours")
# Out:
# Material
# Possible to use Acetate
# Possible to use Metal
# Possible to use 3D-Printed
# Don't use Wood
#
# Luxury & Details
# Luxury Range: Very low, low, Average, High and Very High
# Luxury level: High
# Many different details
# Much outspokenness
# Much metal or metal details
# Many different colours
#
# Background
# Range: Low, Average, High
# Quality of Low importance
# Price can/should be High
# Sustainability of Low importance
# Innovation of Low importance
# Local Production of Low importance
# Craftsmanship of Low importance
#
# Shape
# Range: Do not use, Possible to use, Use and Definitely use
# Possible to use Aviator
# Possible to use Cat Eye
# Use Oval
# Do not use Rectangle
# Use Round
# Do not use Square
# Use Wayfarer
# Use Clubmaster
#
# Colour
# Range: Do not use, Possible to use, Use and Definitely use
# Possible to use White
# Possible to use Black
# Possible to use Grey
# Do not use Orange
# Do not use Yellow
# Do not use Red
# Do not use Brown
# ...
